# %%
# %pylab inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie
sns.set(style='ticks')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## Note i didn't put the directory name because this files is inside same folder as the project am working on
## Summary i created a new folder where i save everything that has to do with this project
data = pd.read_csv('xAPI-Edu-Data.csv')
data
# Out:
#      Gender Nationality Place of birth Educational Stages  Grade Levels  \
# 0      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 1      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 2      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 3      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 4      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 5    Female      KuwaIT         KuwaIT          lowerlevel         G-04
# 6      Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 7      Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 8    Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 9    Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 10     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 11     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 12     Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 13     Male     lebanon        lebanon        MiddleSchool         G-08
# 14   Female      KuwaIT         KuwaIT        MiddleSchool         G-08
# 15   Female      KuwaIT         KuwaIT        MiddleSchool         G-06
# 16     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 17     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 18   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 19     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 20   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 21   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 22     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 23     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 24     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 25     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 26     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 27     Male      KuwaIT         KuwaIT        MiddleSchool         G-08
# 28     Male      KuwaIT         KuwaIT        MiddleSchool         G-08
# 29   Female      KuwaIT         KuwaIT        MiddleSchool         G-08
# ..      ...         ...            ...                 ...          ...
# 450  Female      Jordan         Jordan        MiddleSchool         G-08
# 451  Female      Jordan         Jordan        MiddleSchool         G-08
# 452  Female      Jordan         Jordan        MiddleSchool         G-08
# 453  Female      Jordan         Jordan        MiddleSchool         G-08
# 454  Female      Jordan         Jordan        MiddleSchool         G-08
# 455  Female      Jordan         Jordan        MiddleSchool         G-08
# 456  Female      Jordan         Jordan        MiddleSchool         G-08
# 457  Female      Jordan         Jordan        MiddleSchool         G-08
# 458    Male        Iraq           Iraq        MiddleSchool         G-08
# 459    Male        Iraq           Iraq        MiddleSchool         G-08
# 460    Male        Iraq           Iraq        MiddleSchool         G-08
# 461    Male        Iraq           Iraq        MiddleSchool         G-08
# 462    Male        Iraq           Iraq        MiddleSchool         G-08
# 463    Male        Iraq           Iraq        MiddleSchool         G-08
# 464  Female      Jordan         Jordan        MiddleSchool         G-08
# 465  Female      Jordan         Jordan        MiddleSchool         G-08
# 466  Female      Jordan         Jordan        MiddleSchool         G-08
# 467  Female      Jordan         Jordan        MiddleSchool         G-08
# 468  Female      Jordan         Jordan        MiddleSchool         G-08
# 469  Female      Jordan         Jordan        MiddleSchool         G-08
# 470    Male   Palestine         Jordan        MiddleSchool         G-08
# 471    Male   Palestine         Jordan        MiddleSchool         G-08
# 472    Male   Palestine      Palestine        MiddleSchool         G-08
# 473    Male   Palestine      Palestine        MiddleSchool         G-08
# 474  Female      Jordan         Jordan        MiddleSchool         G-08
# 475  Female      Jordan         Jordan        MiddleSchool         G-08
# 476  Female      Jordan         Jordan        MiddleSchool         G-08
# 477  Female      Jordan         Jordan        MiddleSchool         G-08
# 478  Female      Jordan         Jordan        MiddleSchool         G-08
# 479  Female      Jordan         Jordan        MiddleSchool         G-08
#
#     Section ID      Topic Semester Parent responsible for student  \
# 0            A         IT    First                         Father
# 1            A         IT    First                         Father
# 2            A         IT    First                         Father
# 3            A         IT    First                         Father
# 4            A         IT    First                         Father
# 5            A         IT    First                         Father
# 6            A       Math    First                         Father
# 7            A       Math    First                         Father
# 8            A       Math    First                         Father
# 9            B         IT    First                         Father
# 10           A       Math    First                         Father
# 11           B       Math    First                         Father
# 12           A         IT    First                         Father
# 13           A       Math    First                         Father
# 14           A       Math    First                            mom
# 15           A         IT    First                         Father
# 16           B         IT    First                         Father
# 17           A       Math    First                         Father
# 18           A         IT    First                            mom
# 19           B         IT    First                            mom
# 20           A         IT    First                         Father
# 21           B         IT    First                         Father
# 22           A         IT    First                         Father
# 23           A         IT    First                         Father
# 24           B         IT    First                         Father
# 25           A         IT    First                         Father
# 26           B         IT    First                         Father
# 27           A     Arabic    First                         Father
# 28           A    Science    First                         Father
# 29           A     Arabic    First                         Father
# ..         ...        ...      ...                            ...
# 450          A  Chemistry    First                         Father
# 451          A  Chemistry   Second                         Father
# 452          A    Geology    First                         Father
# 453          A    Geology   Second                         Father
# 454          A    History    First                         Father
# 455          A    History   Second                         Father
# 456          A  Chemistry    First                         Father
# 457          A  Chemistry   Second                         Father
# 458          A  Chemistry    First                         Father
# 459          A  Chemistry   Second                         Father
# 460          A    Geology    First                         Father
# 461          A    Geology   Second                         Father
# 462          A    History    First                         Father
# 463          A    History   Second                         Father
# 464          A  Chemistry    First                            mom
# 465          A  Chemistry   Second                            mom
# 466          A    Geology    First                            mom
# 467          A    Geology   Second                            mom
# 468          A  Chemistry    First                         Father
# 469          A  Chemistry   Second                         Father
# 470          A    History    First                         Father
# 471          A    History   Second                         Father
# 472          A    Geology    First                         Father
# 473          A    Geology   Second                         Father
# 474          A  Chemistry    First                         Father
# 475          A  Chemistry   Second                         Father
# 476          A    Geology    First                         Father
# 477          A    Geology   Second                         Father
# 478          A    History    First                         Father
# 479          A    History   Second                         Father
#
#      Raised hand  Visited resources  Viewing announcements  Discussion groups  \
# 0             15                 16                      2                 20
# 1             20                 20                      3                 25
# 2             10                  7                      0                 30
# 3             30                 25                      5                 35
# 4             40                 50                     12                 50
# 5             42                 30                     13                 70
# 6             35                 12                      0                 17
# 7             50                 10                     15                 22
# 8             12                 21                     16                 50
# 9             70                 80                     25                 70
# 10            50                 88                     30                 80
# 11            19                  6                     19                 12
# 12             5                  1                      0                 11
# 13            20                 14                     12                 19
# 14            62                 70                     44                 60
# 15            30                 40                     22                 66
# 16            36                 30                     20                 80
# 17            55                 13                     35                 90
# 18            69                 15                     36                 96
# 19            70                 50                     40                 99
# 20            60                 60                     33                 90
# 21            10                 12                      4                 80
# 22            15                 21                      2                 90
# 23             2                  0                      2                 50
# 24             0                  2                      3                 70
# 25             8                  7                     30                 40
# 26            19                 19                     25                 40
# 27            25                 15                     12                 33
# 28            75                 85                     52                 43
# 29            30                 90                     33                 35
# ..           ...                ...                    ...                ...
# 450           15                 97                     22                 10
# 451           19                 98                     20                  2
# 452           25                 82                     52                 20
# 453           29                 78                     40                 12
# 454           45                 87                     57                 80
# 455           39                 88                     43                 72
# 456           85                 90                     52                 30
# 457           79                 91                     49                 22
# 458           90                 91                     80                 81
# 459           80                 90                     80                 83
# 460           80                 83                     82                 71
# 461           71                 81                     83                 72
# 462           72                 87                     72                 89
# 463           69                 77                     83                 92
# 464           85                 99                     42                 90
# 465           89                 96                     45                 92
# 466           80                 82                     64                 58
# 467           87                 93                     63                 60
# 468           15                  9                     14                 80
# 469            9                  6                     15                 85
# 470           81                 86                     86                 41
# 471           78                 82                     78                 53
# 472           80                 87                     74                 68
# 473           85                 88                     79                 70
# 474            2                  7                      4                  8
# 475            5                  4                      5                  8
# 476           50                 77                     14                 28
# 477           55                 74                     25                 29
# 478           30                 17                     14                 57
# 479           35                 14                     23                 62
#
#     Parent Answering Survey ParentschoolSatisfaction StudentAbsenceDays  \
# 0                       Yes                     Good            Under-7
# 1                       Yes                     Good            Under-7
# 2                        No                      Bad            Above-7
# 3                        No                      Bad            Above-7
# 4                        No                      Bad            Above-7
# 5                       Yes                      Bad            Above-7
# 6                        No                      Bad            Above-7
# 7                       Yes                     Good            Under-7
# 8                       Yes                     Good            Under-7
# 9                       Yes                     Good            Under-7
# 10                      Yes                     Good            Under-7
# 11                      Yes                     Good            Under-7
# 12                       No                      Bad            Above-7
# 13                       No                      Bad            Above-7
# 14                       No                      Bad            Above-7
# 15                      Yes                     Good            Under-7
# 16                       No                      Bad            Above-7
# 17                       No                      Bad            Above-7
# 18                      Yes                     Good            Under-7
# 19                      Yes                     Good            Under-7
# 20                       No                      Bad            Above-7
# 21                       No                      Bad            Under-7
# 22                       No                      Bad            Under-7
# 23                       No                      Bad            Above-7
# 24                      Yes                     Good            Above-7
# 25                      Yes                     Good            Above-7
# 26                      Yes                      Bad            Under-7
# 27                       No                      Bad            Above-7
# 28                      Yes                     Good            Under-7
# 29                       No                      Bad            Under-7
# ..                      ...                      ...                ...
# 450                     Yes                     Good            Under-7
# 451                     Yes                     Good            Under-7
# 452                     Yes                     Good            Above-7
# 453                     Yes                     Good            Above-7
# 454                     Yes                     Good            Under-7
# 455                     Yes                     Good            Under-7
# 456                     Yes                     Good            Under-7
# 457                     Yes                     Good            Under-7
# 458                     Yes                     Good            Under-7
# 459                     Yes                     Good            Under-7
# 460                     Yes                     Good            Above-7
# 461                     Yes                     Good            Above-7
# 462                     Yes                     Good            Above-7
# 463                     Yes                     Good            Above-7
# 464                     Yes                     Good            Under-7
# 465                     Yes                     Good            Under-7
# 466                     Yes                     Good            Under-7
# 467                     Yes                     Good            Under-7
# 468                      No                      Bad            Above-7
# 469                      No                      Bad            Above-7
# 470                     Yes                     Good            Under-7
# 471                     Yes                     Good            Under-7
# 472                     Yes                     Good            Under-7
# 473                     Yes                     Good            Under-7
# 474                      No                      Bad            Above-7
# 475                      No                      Bad            Above-7
# 476                      No                      Bad            Under-7
# 477                      No                      Bad            Under-7
# 478                      No                      Bad            Above-7
# 479                      No                      Bad            Above-7
#
#             Total
# 0    Middle-Level
# 1    Middle-Level
# 2       Low-Level
# 3       Low-Level
# 4    Middle-Level
# 5    Middle-Level
# 6       Low-Level
# 7    Middle-Level
# 8    Middle-Level
# 9    Middle-Level
# 10     High-Level
# 11   Middle-Level
# 12      Low-Level
# 13      Low-Level
# 14     High-Level
# 15   Middle-Level
# 16   Middle-Level
# 17   Middle-Level
# 18   Middle-Level
# 19     High-Level
# 20   Middle-Level
# 21   Middle-Level
# 22   Middle-Level
# 23      Low-Level
# 24      Low-Level
# 25      Low-Level
# 26   Middle-Level
# 27      Low-Level
# 28   Middle-Level
# 29   Middle-Level
# ..            ...
# 450    High-Level
# 451    High-Level
# 452  Middle-Level
# 453  Middle-Level
# 454  Middle-Level
# 455  Middle-Level
# 456    High-Level
# 457    High-Level
# 458    High-Level
# 459    High-Level
# 460  Middle-Level
# 461  Middle-Level
# 462  Middle-Level
# 463  Middle-Level
# 464    High-Level
# 465    High-Level
# 466    High-Level
# 467    High-Level
# 468     Low-Level
# 469     Low-Level
# 470  Middle-Level
# 471  Middle-Level
# 472  Middle-Level
# 473  Middle-Level
# 474     Low-Level
# 475     Low-Level
# 476  Middle-Level
# 477  Middle-Level
# 478     Low-Level
# 479     Low-Level
#
# [480 rows x 17 columns]

# %%
data['Nationality']
# Out:
# 0         KuwaIT
# 1         KuwaIT
# 2         KuwaIT
# 3         KuwaIT
# 4         KuwaIT
# 5         KuwaIT
# 6         KuwaIT
# 7         KuwaIT
# 8         KuwaIT
# 9         KuwaIT
# 10        KuwaIT
# 11        KuwaIT
# 12        KuwaIT
# 13       lebanon
# 14        KuwaIT
# 15        KuwaIT
# 16        KuwaIT
# 17        KuwaIT
# 18        KuwaIT
# 19        KuwaIT
# 20        KuwaIT
# 21        KuwaIT
# 22        KuwaIT
# 23        KuwaIT
# 24        KuwaIT
# 25        KuwaIT
# 26        KuwaIT
# 27        KuwaIT
# 28        KuwaIT
# 29        KuwaIT
#          ...
# 450       Jordan
# 451       Jordan
# 452       Jordan
# 453       Jordan
# 454       Jordan
# 455       Jordan
# 456       Jordan
# 457       Jordan
# 458         Iraq
# 459         Iraq
# 460         Iraq
# 461         Iraq
# 462         Iraq
# 463         Iraq
# 464       Jordan
# 465       Jordan
# 466       Jordan
# 467       Jordan
# 468       Jordan
# 469       Jordan
# 470    Palestine
# 471    Palestine
# 472    Palestine
# 473    Palestine
# 474       Jordan
# 475       Jordan
# 476       Jordan
# 477       Jordan
# 478       Jordan
# 479       Jordan
# Name: Nationality, Length: 480, dtype: object

# %%
data[['Nationality', 'Topic']]
# Out:
#     Nationality      Topic
# 0        KuwaIT         IT
# 1        KuwaIT         IT
# 2        KuwaIT         IT
# 3        KuwaIT         IT
# 4        KuwaIT         IT
# 5        KuwaIT         IT
# 6        KuwaIT       Math
# 7        KuwaIT       Math
# 8        KuwaIT       Math
# 9        KuwaIT         IT
# 10       KuwaIT       Math
# 11       KuwaIT       Math
# 12       KuwaIT         IT
# 13      lebanon       Math
# 14       KuwaIT       Math
# 15       KuwaIT         IT
# 16       KuwaIT         IT
# 17       KuwaIT       Math
# 18       KuwaIT         IT
# 19       KuwaIT         IT
# 20       KuwaIT         IT
# 21       KuwaIT         IT
# 22       KuwaIT         IT
# 23       KuwaIT         IT
# 24       KuwaIT         IT
# 25       KuwaIT         IT
# 26       KuwaIT         IT
# 27       KuwaIT     Arabic
# 28       KuwaIT    Science
# 29       KuwaIT     Arabic
# ..          ...        ...
# 450      Jordan  Chemistry
# 451      Jordan  Chemistry
# 452      Jordan    Geology
# 453      Jordan    Geology
# 454      Jordan    History
# 455      Jordan    History
# 456      Jordan  Chemistry
# 457      Jordan  Chemistry
# 458        Iraq  Chemistry
# 459        Iraq  Chemistry
# 460        Iraq    Geology
# 461        Iraq    Geology
# 462        Iraq    History
# 463        Iraq    History
# 464      Jordan  Chemistry
# 465      Jordan  Chemistry
# 466      Jordan    Geology
# 467      Jordan    Geology
# 468      Jordan  Chemistry
# 469      Jordan  Chemistry
# 470   Palestine    History
# 471   Palestine    History
# 472   Palestine    Geology
# 473   Palestine    Geology
# 474      Jordan  Chemistry
# 475      Jordan  Chemistry
# 476      Jordan    Geology
# 477      Jordan    Geology
# 478      Jordan    History
# 479      Jordan    History
#
# [480 rows x 2 columns]

# %%
## this is use to get output of a specific value from the data
## here i try to get the data for Male gender

data[data.Gender == 'Male']
gg=data[data.ParentschoolSatisfaction == 'Good']
gg
parentAnsSur
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dde6baaac065> in <module>
#       5 gg=data[data.ParentschoolSatisfaction == 'Good']
#       6 gg
# ----> 7 parentAnsSur
#
# NameError: name 'parentAnsSur' is not defined

# %%
nationality = data['Nationality']

# %%
type(data)

# %%
unique_topic = data['Topic'].value_counts()

unique_topic

# %%
df = pd.DataFrame(data, columns=['Gender'])

# %%
df['Gender'] = df['Gender'].replace('Male,', 'Male')
df['Gender'] = df['Gender'].replace('Female,', 'Female')
df

# %%
gender = data['Gender'].value_counts()

gender

# %%
nationality = data['Nationality'].value_counts()

nationality

# %%
placeOfBirth = data['Place of birth'].value_counts()

gradeLevels = data['Grade Levels'].value_counts()

parentReStd = data['Parent responsible for student'].value_counts()

raisedHand = data['Raised hand'].value_counts()

visitedRes = data['Visited resources'].value_counts()

viewAnno = data['Viewing announcements'].value_counts()

discussionGroups = data['Discussion groups'].value_counts()

parentAnsSur = data['Parent Answering Survey'].value_counts()

parentSchlSat = data['ParentschoolSatisfaction'].value_counts()

studentAbsDays = data['StudentAbsenceDays'].value_counts()

total = data['Total'].value_counts()

# %%
size = [179, 172,28,22,17,12,11,9,7,6,6,6,4,1 ]
style.use('dark_background')
country = ['KuwaIT', 'lebanon', 'Egypt', 'SaudiArabia', 'USA', 'Jordan', 'venzuela', 'Iran',
 'Tunis', 'Morocco', 'Syria', 'Palestine', 'Iraq', 'Lybia']
sizes = size
print(sizes)
labels = list(country)
print(labels)
cols = ['red','green','blue','yellow','gold','yellowgreen','lightcoral','cyan','lightskyblue','blue',
        'orange','purple','pink','indigo']
plt.pie(sizes,  colors = cols, startangle = 45, shadow = None, frame =True, autopct = "%0.1f%%")
plt.rcParams["figure.figsize"] = (25,22)
plt.title('Country distribution')
plt.axis('equal')
plt.legend(labels)
plt.show()

# %%
sns.countplot(x="Topic", data=data, palette="muted");
style.use('dark_background')
plt.grid(True,color='gray')
plt.rcParams["figure.figsize"] = (15,12)
plt.title('Percentage of Students Enrolled in Each Topic')
plt.show()

# %%
sns.countplot(x="Nationality", data=data, palette="muted");
plt.rcParams["figure.figsize"] = (10,8)
plt.title('Percentage of Students Enrolled in Each Topic')
plt.show()

# %%
sns.countplot(x="Gender", data=data, palette="muted");
plt.rcParams["figure.figsize"] = (15,12)
style.use('dark_background')
plt.title('Percentage of Students Enrolled in Each Topic')
plt.show()

# %%
df['Gender']

# %%
data.corr()

# %%
data.info()

# %%
# These are the features names
data.columns

# %%
ave_raisedhands = sum(data['Raised hand'])/len(data['Raised hand'])
ave_visitedResources = sum(data['Visited resources'])/len(data['Visited resources'])
ave_AnnouncementsView = sum(data['Viewing announcements'])/len(data['Viewing announcements'])
unsuccess = data.loc[(data['Raised hand'] >= ave_raisedhands) & (data['Viewing announcements']>=ave_visitedResources) & 
                     (data['Viewing announcements']>=ave_AnnouncementsView)  & (data['Total'] == 'Low-Level')]

# %%
# All features of these two students
print(unsuccess)

# %%
def clean(x):
    x = x.replace("$", "").replace(",", "").replace(" ", "")
    return (x)
data['Gender'] = data['Gender'].apply(clean)

# %%
df = pd.DataFrame({'Nationality':[], 'Total'[:]})
df

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("Nationality", "Total")
ax = sns.barplot(x="Nationality", y="Total", data=tips)

# %%
data.replace('Parent Answering Survey','')
data.columns

# %%
data.replace(columns={'Gender', 'Nationality', 'Place of birth', 'Educational Stages',
       'Grade Levels', 'Section ID', 'Topic', 'Semester','Parent responsible for student', 'Raised hand', 'Visited resources',
       'Viewing announcements', 'Discussion groups', 'Parent Answering Survey': 'ParentAnsweringSurvey',
       'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Total'}, inplace= True)

# %%
data[data.Gender == 'Male']
pss = data[data.ParentschoolSatisfaction == 'Good']
pss
psss = data[data.ParentschoolSatisfaction == 'Bad']

# %%
psss
# Out:
#      Gender Nationality Place of birth Educational Stages  Grade Levels  \
# 2      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 3      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 4      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 5    Female      KuwaIT         KuwaIT          lowerlevel         G-04
# 6      Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 12     Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 13     Male     lebanon        lebanon        MiddleSchool         G-08
# 14   Female      KuwaIT         KuwaIT        MiddleSchool         G-08
# 16     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 17     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 20   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 21   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 22     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 23     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 26     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 27     Male      KuwaIT         KuwaIT        MiddleSchool         G-08
# 29   Female      KuwaIT         KuwaIT        MiddleSchool         G-08
# 33     Male      KuwaIT         KuwaIT          lowerlevel         G-05
# 34     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 35     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 38     Male      KuwaIT         KuwaIT        MiddleSchool         G-06
# 40   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 44   Female      KuwaIT         KuwaIT          HighSchool         G-09
# 46     Male      KuwaIT         KuwaIT          lowerlevel         G-05
# 50   Female      KuwaIT         KuwaIT          HighSchool         G-12
# 52   Female      KuwaIT         KuwaIT          HighSchool         G-12
# 54     Male      KuwaIT         KuwaIT          HighSchool         G-12
# 63     Male      KuwaIT         KuwaIT          HighSchool         G-10
# 64     Male      KuwaIT         KuwaIT          HighSchool         G-10
# 65     Male      KuwaIT         KuwaIT          HighSchool         G-12
# ..      ...         ...            ...                 ...          ...
# 372  Female      Jordan         Jordan          lowerlevel         G-02
# 373  Female      Jordan         Jordan          lowerlevel         G-02
# 374    Male      Jordan         Jordan          lowerlevel         G-02
# 375    Male      Jordan         Jordan          lowerlevel         G-02
# 376    Male      Jordan         Jordan          lowerlevel         G-02
# 377    Male      Jordan         Jordan          lowerlevel         G-02
# 378    Male      Jordan         Jordan          lowerlevel         G-02
# 379    Male      Jordan         Jordan          lowerlevel         G-02
# 380  Female      Jordan         Jordan          lowerlevel         G-02
# 381  Female      Jordan         Jordan          lowerlevel         G-02
# 396    Male      Jordan         Jordan        MiddleSchool         G-07
# 397    Male      Jordan         Jordan        MiddleSchool         G-07
# 406    Male      Jordan         Jordan        MiddleSchool         G-07
# 407    Male      Jordan         Jordan        MiddleSchool         G-07
# 408    Male      Jordan         Jordan        MiddleSchool         G-07
# 409    Male      Jordan         Jordan        MiddleSchool         G-07
# 428    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 429    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 430    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 431    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 432    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 433    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 468  Female      Jordan         Jordan        MiddleSchool         G-08
# 469  Female      Jordan         Jordan        MiddleSchool         G-08
# 474  Female      Jordan         Jordan        MiddleSchool         G-08
# 475  Female      Jordan         Jordan        MiddleSchool         G-08
# 476  Female      Jordan         Jordan        MiddleSchool         G-08
# 477  Female      Jordan         Jordan        MiddleSchool         G-08
# 478  Female      Jordan         Jordan        MiddleSchool         G-08
# 479  Female      Jordan         Jordan        MiddleSchool         G-08
#
#     Section ID      Topic Semester Parent responsible for student  \
# 2            A         IT    First                         Father
# 3            A         IT    First                         Father
# 4            A         IT    First                         Father
# 5            A         IT    First                         Father
# 6            A       Math    First                         Father
# 12           A         IT    First                         Father
# 13           A       Math    First                         Father
# 14           A       Math    First                            mom
# 16           B         IT    First                         Father
# 17           A       Math    First                         Father
# 20           A         IT    First                         Father
# 21           B         IT    First                         Father
# 22           A         IT    First                         Father
# 23           A         IT    First                         Father
# 26           B         IT    First                         Father
# 27           A     Arabic    First                         Father
# 29           A     Arabic    First                         Father
# 33           A    English    First                         Father
# 34           B    Science    First                         Father
# 35           A    English    First                         Father
# 38           A         IT    First                         Father
# 40           A         IT    First                         Father
# 44           A         IT    First                         Father
# 46           A    English    First                         Father
# 50           A    English    First                         Father
# 52           A    English    First                         Father
# 54           A    English    First                            mom
# 63           A         IT    First                         Father
# 64           A         IT    First                         Father
# 65           A    English    First                         Father
# ..         ...        ...      ...                            ...
# 372          A     Arabic    First                         Father
# 373          A     Arabic   Second                         Father
# 374          B     Arabic    First                         Father
# 375          B     Arabic   Second                         Father
# 376          B     Arabic    First                            mom
# 377          B     Arabic   Second                            mom
# 378          B     Arabic    First                         Father
# 379          B     Arabic   Second                         Father
# 380          B     Arabic    First                         Father
# 381          B     Arabic   Second                         Father
# 396          A    Biology    First                         Father
# 397          A    Biology   Second                         Father
# 406          A    Biology    First                            mom
# 407          A    Biology   Second                            mom
# 408          B    Biology    First                         Father
# 409          B    Biology   Second                         Father
# 428          A  Chemistry    First                         Father
# 429          A  Chemistry   Second                         Father
# 430          A    Geology    First                         Father
# 431          A    Geology   Second                         Father
# 432          A    Geology    First                         Father
# 433          A    Geology   Second                         Father
# 468          A  Chemistry    First                         Father
# 469          A  Chemistry   Second                         Father
# 474          A  Chemistry    First                         Father
# 475          A  Chemistry   Second                         Father
# 476          A    Geology    First                         Father
# 477          A    Geology   Second                         Father
# 478          A    History    First                         Father
# 479          A    History   Second                         Father
#
#      Raised hand  Visited resources  Viewing announcements  Discussion groups  \
# 2             10                  7                      0                 30
# 3             30                 25                      5                 35
# 4             40                 50                     12                 50
# 5             42                 30                     13                 70
# 6             35                 12                      0                 17
# 12             5                  1                      0                 11
# 13            20                 14                     12                 19
# 14            62                 70                     44                 60
# 16            36                 30                     20                 80
# 17            55                 13                     35                 90
# 20            60                 60                     33                 90
# 21            10                 12                      4                 80
# 22            15                 21                      2                 90
# 23             2                  0                      2                 50
# 26            19                 19                     25                 40
# 27            25                 15                     12                 33
# 29            30                 90                     33                 35
# 33             8                 22                      9                 40
# 34            12                 11                      8                 40
# 35            10                 12                     17                 30
# 38             0                  0                      0                  4
# 40            14                 13                      3                 70
# 44            33                 33                     30                 90
# 46             7                 10                      1                 30
# 50            20                 14                     12                 70
# 52            55                 90                     16                 40
# 54            12                 50                      8                 30
# 63            17                 13                     16                 12
# 64             0                  5                      7                  2
# 65            13                  5                     18                 19
# ..           ...                ...                    ...                ...
# 372           10                 20                     22                 97
# 373            5                  9                     19                 98
# 374           10                 10                     40                 51
# 375           35                  2                     29                 23
# 376           20                 90                     50                 61
# 377           32                 82                     59                 63
# 378           10                 30                     50                 91
# 379           12                 22                     59                 83
# 380           11                 20                     20                 98
# 381           10                 12                     29                 93
# 396           80                 80                     46                 61
# 397           85                 82                     59                 63
# 406            2                  9                     10                  1
# 407            3                  8                     19                  3
# 408           50                 79                     10                 31
# 409           53                 88                      9                 33
# 428           10                  0                      2                 41
# 429           11                  2                      9                 49
# 430           85                 89                     22                 61
# 431           80                 89                     23                 68
# 432           95                 87                     62                 81
# 433           87                 79                     73                 98
# 468           15                  9                     14                 80
# 469            9                  6                     15                 85
# 474            2                  7                      4                  8
# 475            5                  4                      5                  8
# 476           50                 77                     14                 28
# 477           55                 74                     25                 29
# 478           30                 17                     14                 57
# 479           35                 14                     23                 62
#
#     Parent Answering Survey ParentschoolSatisfaction StudentAbsenceDays  \
# 2                        No                      Bad            Above-7
# 3                        No                      Bad            Above-7
# 4                        No                      Bad            Above-7
# 5                       Yes                      Bad            Above-7
# 6                        No                      Bad            Above-7
# 12                       No                      Bad            Above-7
# 13                       No                      Bad            Above-7
# 14                       No                      Bad            Above-7
# 16                       No                      Bad            Above-7
# 17                       No                      Bad            Above-7
# 20                       No                      Bad            Above-7
# 21                       No                      Bad            Under-7
# 22                       No                      Bad            Under-7
# 23                       No                      Bad            Above-7
# 26                      Yes                      Bad            Under-7
# 27                       No                      Bad            Above-7
# 29                       No                      Bad            Under-7
# 33                       No                      Bad            Above-7
# 34                       No                      Bad            Above-7
# 35                       No                      Bad            Above-7
# 38                       No                      Bad            Above-7
# 40                       No                      Bad            Above-7
# 44                       No                      Bad            Under-7
# 46                       No                      Bad            Above-7
# 50                       No                      Bad            Above-7
# 52                       No                      Bad            Under-7
# 54                       No                      Bad            Above-7
# 63                      Yes                      Bad            Under-7
# 64                       No                      Bad            Above-7
# 65                       No                      Bad            Above-7
# ..                      ...                      ...                ...
# 372                      No                      Bad            Above-7
# 373                      No                      Bad            Above-7
# 374                      No                      Bad            Above-7
# 375                      No                      Bad            Above-7
# 376                     Yes                      Bad            Above-7
# 377                     Yes                      Bad            Above-7
# 378                     Yes                      Bad            Above-7
# 379                     Yes                      Bad            Above-7
# 380                      No                      Bad            Above-7
# 381                      No                      Bad            Above-7
# 396                     Yes                      Bad            Under-7
# 397                     Yes                      Bad            Under-7
# 406                      No                      Bad            Above-7
# 407                      No                      Bad            Above-7
# 408                      No                      Bad            Under-7
# 409                      No                      Bad            Under-7
# 428                      No                      Bad            Above-7
# 429                      No                      Bad            Above-7
# 430                      No                      Bad            Under-7
# 431                      No                      Bad            Under-7
# 432                      No                      Bad            Under-7
# 433                      No                      Bad            Under-7
# 468                      No                      Bad            Above-7
# 469                      No                      Bad            Above-7
# 474                      No                      Bad            Above-7
# 475                      No                      Bad            Above-7
# 476                      No                      Bad            Under-7
# 477                      No                      Bad            Under-7
# 478                      No                      Bad            Above-7
# 479                      No                      Bad            Above-7
#
#             Total
# 2       Low-Level
# 3       Low-Level
# 4    Middle-Level
# 5    Middle-Level
# 6       Low-Level
# 12      Low-Level
# 13      Low-Level
# 14     High-Level
# 16   Middle-Level
# 17   Middle-Level
# 20   Middle-Level
# 21   Middle-Level
# 22   Middle-Level
# 23      Low-Level
# 26   Middle-Level
# 27      Low-Level
# 29   Middle-Level
# 33      Low-Level
# 34      Low-Level
# 35      Low-Level
# 38      Low-Level
# 40      Low-Level
# 44   Middle-Level
# 46      Low-Level
# 50      Low-Level
# 52   Middle-Level
# 54      Low-Level
# 63   Middle-Level
# 64      Low-Level
# 65      Low-Level
# ..            ...
# 372     Low-Level
# 373     Low-Level
# 374     Low-Level
# 375     Low-Level
# 376  Middle-Level
# 377  Middle-Level
# 378     Low-Level
# 379     Low-Level
# 380     Low-Level
# 381     Low-Level
# 396  Middle-Level
# 397  Middle-Level
# 406     Low-Level
# 407     Low-Level
# 408  Middle-Level
# 409  Middle-Level
# 428     Low-Level
# 429     Low-Level
# 430    High-Level
# 431    High-Level
# 432  Middle-Level
# 433  Middle-Level
# 468     Low-Level
# 469     Low-Level
# 474     Low-Level
# 475     Low-Level
# 476  Middle-Level
# 477  Middle-Level
# 478     Low-Level
# 479     Low-Level
#
# [188 rows x 17 columns]

# %%
#calling the parents who took a specific action in the dataframe

pas=data.loc[data['Parent Answering Survey']=='Yes']
pas
psas=data.loc[data['Parent Answering Survey']=='No']

# %%
data2=(data1.loc[data['Parent Answering Survey']=='Yes'])
data2
# Out:
#      Gender  Nationality Place of birth Educational Stages  Grade Levels  \
# 0      Male       KuwaIT         KuwaIT          lowerlevel         G-04
# 1      Male       KuwaIT         KuwaIT          lowerlevel         G-04
# 5    Female       KuwaIT         KuwaIT          lowerlevel         G-04
# 7      Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 8    Female       KuwaIT         KuwaIT        MiddleSchool         G-07
# 9    Female       KuwaIT         KuwaIT        MiddleSchool         G-07
# 10     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 11     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 15   Female       KuwaIT         KuwaIT        MiddleSchool         G-06
# 18   Female       KuwaIT         KuwaIT        MiddleSchool         G-07
# 19     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 24     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 25     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 26     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 28     Male       KuwaIT         KuwaIT        MiddleSchool         G-08
# 30   Female       KuwaIT         KuwaIT        MiddleSchool         G-08
# 31     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 32   Female       KuwaIT         KuwaIT          lowerlevel         G-07
# 36     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 37   Female        Egypt          Egypt        MiddleSchool         G-07
# 39   Female  SaudiArabia    SaudiArabia        MiddleSchool         G-07
# 42     Male       KuwaIT         KuwaIT          HighSchool         G-09
# 43   Female       KuwaIT         KuwaIT          HighSchool         G-09
# 47   Female       KuwaIT         KuwaIT          HighSchool         G-12
# 48   Female       KuwaIT         KuwaIT          HighSchool         G-12
# 49   Female       KuwaIT         KuwaIT          HighSchool         G-12
# 53   Female       KuwaIT         KuwaIT          HighSchool         G-11
# 55     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 56     Male          USA            USA        MiddleSchool         G-08
# 57     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# ..      ...          ...            ...                 ...          ...
# 442    Male       Jordan         Jordan        MiddleSchool         G-08
# 443    Male       Jordan         Jordan        MiddleSchool         G-08
# 444    Male       Jordan         Jordan        MiddleSchool         G-08
# 445    Male       Jordan         Jordan        MiddleSchool         G-08
# 446    Male       Jordan         Jordan        MiddleSchool         G-08
# 447    Male       Jordan         Jordan        MiddleSchool         G-08
# 448    Male       Jordan         Jordan        MiddleSchool         G-08
# 449    Male       Jordan         Jordan        MiddleSchool         G-08
# 450  Female       Jordan         Jordan        MiddleSchool         G-08
# 451  Female       Jordan         Jordan        MiddleSchool         G-08
# 452  Female       Jordan         Jordan        MiddleSchool         G-08
# 453  Female       Jordan         Jordan        MiddleSchool         G-08
# 454  Female       Jordan         Jordan        MiddleSchool         G-08
# 455  Female       Jordan         Jordan        MiddleSchool         G-08
# 456  Female       Jordan         Jordan        MiddleSchool         G-08
# 457  Female       Jordan         Jordan        MiddleSchool         G-08
# 458    Male         Iraq           Iraq        MiddleSchool         G-08
# 459    Male         Iraq           Iraq        MiddleSchool         G-08
# 460    Male         Iraq           Iraq        MiddleSchool         G-08
# 461    Male         Iraq           Iraq        MiddleSchool         G-08
# 462    Male         Iraq           Iraq        MiddleSchool         G-08
# 463    Male         Iraq           Iraq        MiddleSchool         G-08
# 464  Female       Jordan         Jordan        MiddleSchool         G-08
# 465  Female       Jordan         Jordan        MiddleSchool         G-08
# 466  Female       Jordan         Jordan        MiddleSchool         G-08
# 467  Female       Jordan         Jordan        MiddleSchool         G-08
# 470    Male    Palestine         Jordan        MiddleSchool         G-08
# 471    Male    Palestine         Jordan        MiddleSchool         G-08
# 472    Male    Palestine      Palestine        MiddleSchool         G-08
# 473    Male    Palestine      Palestine        MiddleSchool         G-08
#
#     Section ID      Topic Semester Parent responsible for student  \
# 0            A         IT    First                         Father
# 1            A         IT    First                         Father
# 5            A         IT    First                         Father
# 7            A       Math    First                         Father
# 8            A       Math    First                         Father
# 9            B         IT    First                         Father
# 10           A       Math    First                         Father
# 11           B       Math    First                         Father
# 15           A         IT    First                         Father
# 18           A         IT    First                            mom
# 19           B         IT    First                            mom
# 24           B         IT    First                         Father
# 25           A         IT    First                         Father
# 26           B         IT    First                         Father
# 28           A    Science    First                         Father
# 30           A     Arabic    First                         Father
# 31           A         IT    First                         Father
# 32           A         IT    First                         Father
# 36           B    Science    First                            mom
# 37           A         IT    First                         Father
# 39           B    Science    First                         Father
# 42           A         IT    First                         Father
# 43           A         IT    First                         Father
# 47           A    English    First                            mom
# 48           A    English    First                            mom
# 49           A    English    First                         Father
# 53           A    Science    First                            mom
# 55           A       Math    First                         Father
# 56           B       Math    First                         Father
# 57           A       Math    First                         Father
# ..         ...        ...      ...                            ...
# 442          A    History    First                            mom
# 443          A    History   Second                            mom
# 444          A  Chemistry    First                            mom
# 445          A  Chemistry   Second                            mom
# 446          A    Geology    First                            mom
# 447          A    Geology   Second                            mom
# 448          A    History    First                            mom
# 449          A    History   Second                            mom
# 450          A  Chemistry    First                         Father
# 451          A  Chemistry   Second                         Father
# 452          A    Geology    First                         Father
# 453          A    Geology   Second                         Father
# 454          A    History    First                         Father
# 455          A    History   Second                         Father
# 456          A  Chemistry    First                         Father
# 457          A  Chemistry   Second                         Father
# 458          A  Chemistry    First                         Father
# 459          A  Chemistry   Second                         Father
# 460          A    Geology    First                         Father
# 461          A    Geology   Second                         Father
# 462          A    History    First                         Father
# 463          A    History   Second                         Father
# 464          A  Chemistry    First                            mom
# 465          A  Chemistry   Second                            mom
# 466          A    Geology    First                            mom
# 467          A    Geology   Second                            mom
# 470          A    History    First                         Father
# 471          A    History   Second                         Father
# 472          A    Geology    First                         Father
# 473          A    Geology   Second                         Father
#
#      Raised hand  Visited resources  Viewing announcements  Discussion groups  \
# 0             15                 16                      2                 20
# 1             20                 20                      3                 25
# 5             42                 30                     13                 70
# 7             50                 10                     15                 22
# 8             12                 21                     16                 50
# 9             70                 80                     25                 70
# 10            50                 88                     30                 80
# 11            19                  6                     19                 12
# 15            30                 40                     22                 66
# 18            69                 15                     36                 96
# 19            70                 50                     40                 99
# 24             0                  2                      3                 70
# 25             8                  7                     30                 40
# 26            19                 19                     25                 40
# 28            75                 85                     52                 43
# 30            35                 80                     50                 70
# 31             4                  5                     40                 16
# 32             2                 19                     10                 50
# 36             8                  6                      4                 22
# 37            45                 54                     26                 90
# 39            50                 90                     37                 70
# 42            10                 12                      7                 33
# 43            30                 35                     28                 90
# 47            70                  4                     39                 90
# 48            13                 80                     40                 88
# 49            29                 39                     50                 77
# 53            49                 70                     19                 75
# 55            16                 14                      6                 20
# 56            19                  5                      4                  1
# 57             5                  2                      6                  5
# ..           ...                ...                    ...                ...
# 442           69                 77                     76                 75
# 443           70                 76                     65                 70
# 444           75                 72                     64                 39
# 445           72                 76                     66                 40
# 446           77                 82                     74                 79
# 447           71                 84                     67                 80
# 448           87                 92                     74                 89
# 449           81                 84                     77                 85
# 450           15                 97                     22                 10
# 451           19                 98                     20                  2
# 452           25                 82                     52                 20
# 453           29                 78                     40                 12
# 454           45                 87                     57                 80
# 455           39                 88                     43                 72
# 456           85                 90                     52                 30
# 457           79                 91                     49                 22
# 458           90                 91                     80                 81
# 459           80                 90                     80                 83
# 460           80                 83                     82                 71
# 461           71                 81                     83                 72
# 462           72                 87                     72                 89
# 463           69                 77                     83                 92
# 464           85                 99                     42                 90
# 465           89                 96                     45                 92
# 466           80                 82                     64                 58
# 467           87                 93                     63                 60
# 470           81                 86                     86                 41
# 471           78                 82                     78                 53
# 472           80                 87                     74                 68
# 473           85                 88                     79                 70
#
#     Parent Answering Survey ParentschoolSatisfaction StudentAbsenceDays  \
# 0                       Yes                     Good            Under-7
# 1                       Yes                     Good            Under-7
# 5                       Yes                      Bad            Above-7
# 7                       Yes                     Good            Under-7
# 8                       Yes                     Good            Under-7
# 9                       Yes                     Good            Under-7
# 10                      Yes                     Good            Under-7
# 11                      Yes                     Good            Under-7
# 15                      Yes                     Good            Under-7
# 18                      Yes                     Good            Under-7
# 19                      Yes                     Good            Under-7
# 24                      Yes                     Good            Above-7
# 25                      Yes                     Good            Above-7
# 26                      Yes                      Bad            Under-7
# 28                      Yes                     Good            Under-7
# 30                      Yes                     Good            Under-7
# 31                      Yes                     Good            Above-7
# 32                      Yes                     Good            Above-7
# 36                      Yes                     Good            Above-7
# 37                      Yes                     Good            Under-7
# 39                      Yes                     Good            Under-7
# 42                      Yes                     Good            Above-7
# 43                      Yes                     Good            Under-7
# 47                      Yes                     Good            Under-7
# 48                      Yes                     Good            Under-7
# 49                      Yes                     Good            Under-7
# 53                      Yes                     Good            Under-7
# 55                      Yes                     Good            Above-7
# 56                      Yes                     Good            Above-7
# 57                      Yes                     Good            Above-7
# ..                      ...                      ...                ...
# 442                     Yes                     Good            Above-7
# 443                     Yes                     Good            Above-7
# 444                     Yes                     Good            Above-7
# 445                     Yes                     Good            Above-7
# 446                     Yes                     Good            Under-7
# 447                     Yes                     Good            Under-7
# 448                     Yes                     Good            Under-7
# 449                     Yes                     Good            Under-7
# 450                     Yes                     Good            Under-7
# 451                     Yes                     Good            Under-7
# 452                     Yes                     Good            Above-7
# 453                     Yes                     Good            Above-7
# 454                     Yes                     Good            Under-7
# 455                     Yes                     Good            Under-7
# 456                     Yes                     Good            Under-7
# 457                     Yes                     Good            Under-7
# 458                     Yes                     Good            Under-7
# 459                     Yes                     Good            Under-7
# 460                     Yes                     Good            Above-7
# 461                     Yes                     Good            Above-7
# 462                     Yes                     Good            Above-7
# 463                     Yes                     Good            Above-7
# 464                     Yes                     Good            Under-7
# 465                     Yes                     Good            Under-7
# 466                     Yes                     Good            Under-7
# 467                     Yes                     Good            Under-7
# 470                     Yes                     Good            Under-7
# 471                     Yes                     Good            Under-7
# 472                     Yes                     Good            Under-7
# 473                     Yes                     Good            Under-7
#
#             Total
# 0    Middle-Level
# 1    Middle-Level
# 5    Middle-Level
# 7    Middle-Level
# 8    Middle-Level
# 9    Middle-Level
# 10     High-Level
# 11   Middle-Level
# 15   Middle-Level
# 18   Middle-Level
# 19     High-Level
# 24      Low-Level
# 25      Low-Level
# 26   Middle-Level
# 28   Middle-Level
# 30     High-Level
# 31      Low-Level
# 32      Low-Level
# 36      Low-Level
# 37   Middle-Level
# 39   Middle-Level
# 42      Low-Level
# 43   Middle-Level
# 47     High-Level
# 48     High-Level
# 49   Middle-Level
# 53     High-Level
# 55      Low-Level
# 56      Low-Level
# 57      Low-Level
# ..            ...
# 442  Middle-Level
# 443  Middle-Level
# 444     Low-Level
# 445     Low-Level
# 446  Middle-Level
# 447  Middle-Level
# 448    High-Level
# 449    High-Level
# 450    High-Level
# 451    High-Level
# 452  Middle-Level
# 453  Middle-Level
# 454  Middle-Level
# 455  Middle-Level
# 456    High-Level
# 457    High-Level
# 458    High-Level
# 459    High-Level
# 460  Middle-Level
# 461  Middle-Level
# 462  Middle-Level
# 463  Middle-Level
# 464    High-Level
# 465    High-Level
# 466    High-Level
# 467    High-Level
# 470  Middle-Level
# 471  Middle-Level
# 472  Middle-Level
# 473  Middle-Level
#
# [270 rows x 17 columns]

# %%
psas
# Out:
#      Gender Nationality Place of birth Educational Stages  Grade Levels  \
# 2      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 3      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 4      Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 6      Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 12     Male      KuwaIT         KuwaIT          lowerlevel         G-04
# 13     Male     lebanon        lebanon        MiddleSchool         G-08
# 14   Female      KuwaIT         KuwaIT        MiddleSchool         G-08
# 16     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 17     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 20   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 21   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 22     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 23     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 27     Male      KuwaIT         KuwaIT        MiddleSchool         G-08
# 29   Female      KuwaIT         KuwaIT        MiddleSchool         G-08
# 33     Male      KuwaIT         KuwaIT          lowerlevel         G-05
# 34     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 35     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 38     Male      KuwaIT         KuwaIT        MiddleSchool         G-06
# 40   Female      KuwaIT         KuwaIT        MiddleSchool         G-07
# 41     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 44   Female      KuwaIT         KuwaIT          HighSchool         G-09
# 45     Male      KuwaIT         KuwaIT        MiddleSchool         G-07
# 46     Male      KuwaIT         KuwaIT          lowerlevel         G-05
# 50   Female      KuwaIT         KuwaIT          HighSchool         G-12
# 51     Male      KuwaIT         KuwaIT          HighSchool         G-12
# 52   Female      KuwaIT         KuwaIT          HighSchool         G-12
# 54     Male      KuwaIT         KuwaIT          HighSchool         G-12
# 59   Female         USA            USA        MiddleSchool         G-07
# 60   Female      Jordan         Jordan          lowerlevel         G-05
# ..      ...         ...            ...                 ...          ...
# 380  Female      Jordan         Jordan          lowerlevel         G-02
# 381  Female      Jordan         Jordan          lowerlevel         G-02
# 388    Male      Jordan    SaudiArabia          lowerlevel         G-02
# 389    Male      Jordan    SaudiArabia          lowerlevel         G-02
# 400    Male      Jordan         Jordan        MiddleSchool         G-07
# 401    Male      Jordan         Jordan        MiddleSchool         G-07
# 402    Male      Jordan         Jordan        MiddleSchool         G-07
# 403    Male      Jordan         Jordan        MiddleSchool         G-07
# 406    Male      Jordan         Jordan        MiddleSchool         G-07
# 407    Male      Jordan         Jordan        MiddleSchool         G-07
# 408    Male      Jordan         Jordan        MiddleSchool         G-07
# 409    Male      Jordan         Jordan        MiddleSchool         G-07
# 410  Female      Jordan         Jordan        MiddleSchool         G-07
# 411  Female      Jordan         Jordan        MiddleSchool         G-07
# 414  Female       Lybia          Lybia        MiddleSchool         G-07
# 415  Female       Lybia          Lybia        MiddleSchool         G-07
# 428    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 429    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 430    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 431    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 432    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 433    Male      Jordan    SaudiArabia        MiddleSchool         G-08
# 468  Female      Jordan         Jordan        MiddleSchool         G-08
# 469  Female      Jordan         Jordan        MiddleSchool         G-08
# 474  Female      Jordan         Jordan        MiddleSchool         G-08
# 475  Female      Jordan         Jordan        MiddleSchool         G-08
# 476  Female      Jordan         Jordan        MiddleSchool         G-08
# 477  Female      Jordan         Jordan        MiddleSchool         G-08
# 478  Female      Jordan         Jordan        MiddleSchool         G-08
# 479  Female      Jordan         Jordan        MiddleSchool         G-08
#
#     Section ID      Topic Semester Parent responsible for student  \
# 2            A         IT    First                         Father
# 3            A         IT    First                         Father
# 4            A         IT    First                         Father
# 6            A       Math    First                         Father
# 12           A         IT    First                         Father
# 13           A       Math    First                         Father
# 14           A       Math    First                            mom
# 16           B         IT    First                         Father
# 17           A       Math    First                         Father
# 20           A         IT    First                         Father
# 21           B         IT    First                         Father
# 22           A         IT    First                         Father
# 23           A         IT    First                         Father
# 27           A     Arabic    First                         Father
# 29           A     Arabic    First                         Father
# 33           A    English    First                         Father
# 34           B    Science    First                         Father
# 35           A    English    First                         Father
# 38           A         IT    First                         Father
# 40           A         IT    First                         Father
# 41           A         IT    First                         Father
# 44           A         IT    First                         Father
# 45           A      Quran    First                         Father
# 46           A    English    First                         Father
# 50           A    English    First                         Father
# 51           A    English    First                         Father
# 52           A    English    First                         Father
# 54           A    English    First                            mom
# 59           A       Math    First                         Father
# 60           A    English    First                            mom
# ..         ...        ...      ...                            ...
# 380          B     Arabic    First                         Father
# 381          B     Arabic   Second                         Father
# 388          B     Arabic    First                            mom
# 389          B     Arabic   Second                            mom
# 400          A    Biology    First                         Father
# 401          A    Biology   Second                         Father
# 402          A    Biology    First                         Father
# 403          A    Biology   Second                         Father
# 406          A    Biology    First                            mom
# 407          A    Biology   Second                            mom
# 408          B    Biology    First                         Father
# 409          B    Biology   Second                         Father
# 410          B    Biology    First                            mom
# 411          B    Biology   Second                            mom
# 414          B    Biology    First                            mom
# 415          B    Biology   Second                            mom
# 428          A  Chemistry    First                         Father
# 429          A  Chemistry   Second                         Father
# 430          A    Geology    First                         Father
# 431          A    Geology   Second                         Father
# 432          A    Geology    First                         Father
# 433          A    Geology   Second                         Father
# 468          A  Chemistry    First                         Father
# 469          A  Chemistry   Second                         Father
# 474          A  Chemistry    First                         Father
# 475          A  Chemistry   Second                         Father
# 476          A    Geology    First                         Father
# 477          A    Geology   Second                         Father
# 478          A    History    First                         Father
# 479          A    History   Second                         Father
#
#      Raised hand  Visited resources  Viewing announcements  Discussion groups  \
# 2             10                  7                      0                 30
# 3             30                 25                      5                 35
# 4             40                 50                     12                 50
# 6             35                 12                      0                 17
# 12             5                  1                      0                 11
# 13            20                 14                     12                 19
# 14            62                 70                     44                 60
# 16            36                 30                     20                 80
# 17            55                 13                     35                 90
# 20            60                 60                     33                 90
# 21            10                 12                      4                 80
# 22            15                 21                      2                 90
# 23             2                  0                      2                 50
# 27            25                 15                     12                 33
# 29            30                 90                     33                 35
# 33             8                 22                      9                 40
# 34            12                 11                      8                 40
# 35            10                 12                     17                 30
# 38             0                  0                      0                  4
# 40            14                 13                      3                 70
# 41            19                 20                     16                 50
# 44            33                 33                     30                 90
# 45            20                 12                     15                 70
# 46             7                 10                      1                 30
# 50            20                 14                     12                 70
# 51            39                 15                     16                 50
# 52            55                 90                     16                 40
# 54            12                 50                      8                 30
# 59            27                 22                     22                 40
# 60            21                 10                     28                 20
# ..           ...                ...                    ...                ...
# 380           11                 20                     20                 98
# 381           10                 12                     29                 93
# 388            4                 10                     11                  7
# 389            5                  0                      1                  8
# 400           39                 71                     40                 26
# 401           35                 80                     34                 22
# 402           76                 81                     80                 86
# 403           65                 89                     64                 82
# 406            2                  9                     10                  1
# 407            3                  8                     19                  3
# 408           50                 79                     10                 31
# 409           53                 88                      9                 33
# 410           70                 89                     12                 21
# 411           59                 90                     19                 43
# 414           10                  9                      2                  1
# 415            9                  7                      9                  3
# 428           10                  0                      2                 41
# 429           11                  2                      9                 49
# 430           85                 89                     22                 61
# 431           80                 89                     23                 68
# 432           95                 87                     62                 81
# 433           87                 79                     73                 98
# 468           15                  9                     14                 80
# 469            9                  6                     15                 85
# 474            2                  7                      4                  8
# 475            5                  4                      5                  8
# 476           50                 77                     14                 28
# 477           55                 74                     25                 29
# 478           30                 17                     14                 57
# 479           35                 14                     23                 62
#
#     Parent Answering Survey ParentschoolSatisfaction StudentAbsenceDays  \
# 2                        No                      Bad            Above-7
# 3                        No                      Bad            Above-7
# 4                        No                      Bad            Above-7
# 6                        No                      Bad            Above-7
# 12                       No                      Bad            Above-7
# 13                       No                      Bad            Above-7
# 14                       No                      Bad            Above-7
# 16                       No                      Bad            Above-7
# 17                       No                      Bad            Above-7
# 20                       No                      Bad            Above-7
# 21                       No                      Bad            Under-7
# 22                       No                      Bad            Under-7
# 23                       No                      Bad            Above-7
# 27                       No                      Bad            Above-7
# 29                       No                      Bad            Under-7
# 33                       No                      Bad            Above-7
# 34                       No                      Bad            Above-7
# 35                       No                      Bad            Above-7
# 38                       No                      Bad            Above-7
# 40                       No                      Bad            Above-7
# 41                       No                     Good            Under-7
# 44                       No                      Bad            Under-7
# 45                       No                     Good            Above-7
# 46                       No                      Bad            Above-7
# 50                       No                      Bad            Above-7
# 51                       No                     Good            Above-7
# 52                       No                      Bad            Under-7
# 54                       No                      Bad            Above-7
# 59                       No                     Good            Under-7
# 60                       No                     Good            Above-7
# ..                      ...                      ...                ...
# 380                      No                      Bad            Above-7
# 381                      No                      Bad            Above-7
# 388                      No                     Good            Above-7
# 389                      No                     Good            Above-7
# 400                      No                     Good            Above-7
# 401                      No                     Good            Above-7
# 402                      No                     Good            Under-7
# 403                      No                     Good            Under-7
# 406                      No                      Bad            Above-7
# 407                      No                      Bad            Above-7
# 408                      No                      Bad            Under-7
# 409                      No                      Bad            Under-7
# 410                      No                     Good            Under-7
# 411                      No                     Good            Under-7
# 414                      No                     Good            Above-7
# 415                      No                     Good            Above-7
# 428                      No                      Bad            Above-7
# 429                      No                      Bad            Above-7
# 430                      No                      Bad            Under-7
# 431                      No                      Bad            Under-7
# 432                      No                      Bad            Under-7
# 433                      No                      Bad            Under-7
# 468                      No                      Bad            Above-7
# 469                      No                      Bad            Above-7
# 474                      No                      Bad            Above-7
# 475                      No                      Bad            Above-7
# 476                      No                      Bad            Under-7
# 477                      No                      Bad            Under-7
# 478                      No                      Bad            Above-7
# 479                      No                      Bad            Above-7
#
#             Total
# 2       Low-Level
# 3       Low-Level
# 4    Middle-Level
# 6       Low-Level
# 12      Low-Level
# 13      Low-Level
# 14     High-Level
# 16   Middle-Level
# 17   Middle-Level
# 20   Middle-Level
# 21   Middle-Level
# 22   Middle-Level
# 23      Low-Level
# 27      Low-Level
# 29   Middle-Level
# 33      Low-Level
# 34      Low-Level
# 35      Low-Level
# 38      Low-Level
# 40      Low-Level
# 41   Middle-Level
# 44   Middle-Level
# 45      Low-Level
# 46      Low-Level
# 50      Low-Level
# 51      Low-Level
# 52   Middle-Level
# 54      Low-Level
# 59   Middle-Level
# 60      Low-Level
# ..            ...
# 380     Low-Level
# 381     Low-Level
# 388     Low-Level
# 389     Low-Level
# 400  Middle-Level
# 401  Middle-Level
# 402    High-Level
# 403    High-Level
# 406     Low-Level
# 407     Low-Level
# 408  Middle-Level
# 409  Middle-Level
# 410    High-Level
# 411    High-Level
# 414     Low-Level
# 415     Low-Level
# 428     Low-Level
# 429     Low-Level
# 430    High-Level
# 431    High-Level
# 432  Middle-Level
# 433  Middle-Level
# 468     Low-Level
# 469     Low-Level
# 474     Low-Level
# 475     Low-Level
# 476  Middle-Level
# 477  Middle-Level
# 478     Low-Level
# 479     Low-Level
#
# [210 rows x 17 columns]

# %%
pas
# Out:
#      Gender  Nationality Place of birth Educational Stages  Grade Levels  \
# 0      Male       KuwaIT         KuwaIT          lowerlevel         G-04
# 1      Male       KuwaIT         KuwaIT          lowerlevel         G-04
# 5    Female       KuwaIT         KuwaIT          lowerlevel         G-04
# 7      Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 8    Female       KuwaIT         KuwaIT        MiddleSchool         G-07
# 9    Female       KuwaIT         KuwaIT        MiddleSchool         G-07
# 10     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 11     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 15   Female       KuwaIT         KuwaIT        MiddleSchool         G-06
# 18   Female       KuwaIT         KuwaIT        MiddleSchool         G-07
# 19     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 24     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 25     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 26     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 28     Male       KuwaIT         KuwaIT        MiddleSchool         G-08
# 30   Female       KuwaIT         KuwaIT        MiddleSchool         G-08
# 31     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 32   Female       KuwaIT         KuwaIT          lowerlevel         G-07
# 36     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 37   Female        Egypt          Egypt        MiddleSchool         G-07
# 39   Female  SaudiArabia    SaudiArabia        MiddleSchool         G-07
# 42     Male       KuwaIT         KuwaIT          HighSchool         G-09
# 43   Female       KuwaIT         KuwaIT          HighSchool         G-09
# 47   Female       KuwaIT         KuwaIT          HighSchool         G-12
# 48   Female       KuwaIT         KuwaIT          HighSchool         G-12
# 49   Female       KuwaIT         KuwaIT          HighSchool         G-12
# 53   Female       KuwaIT         KuwaIT          HighSchool         G-11
# 55     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# 56     Male          USA            USA        MiddleSchool         G-08
# 57     Male       KuwaIT         KuwaIT        MiddleSchool         G-07
# ..      ...          ...            ...                 ...          ...
# 442    Male       Jordan         Jordan        MiddleSchool         G-08
# 443    Male       Jordan         Jordan        MiddleSchool         G-08
# 444    Male       Jordan         Jordan        MiddleSchool         G-08
# 445    Male       Jordan         Jordan        MiddleSchool         G-08
# 446    Male       Jordan         Jordan        MiddleSchool         G-08
# 447    Male       Jordan         Jordan        MiddleSchool         G-08
# 448    Male       Jordan         Jordan        MiddleSchool         G-08
# 449    Male       Jordan         Jordan        MiddleSchool         G-08
# 450  Female       Jordan         Jordan        MiddleSchool         G-08
# 451  Female       Jordan         Jordan        MiddleSchool         G-08
# 452  Female       Jordan         Jordan        MiddleSchool         G-08
# 453  Female       Jordan         Jordan        MiddleSchool         G-08
# 454  Female       Jordan         Jordan        MiddleSchool         G-08
# 455  Female       Jordan         Jordan        MiddleSchool         G-08
# 456  Female       Jordan         Jordan        MiddleSchool         G-08
# 457  Female       Jordan         Jordan        MiddleSchool         G-08
# 458    Male         Iraq           Iraq        MiddleSchool         G-08
# 459    Male         Iraq           Iraq        MiddleSchool         G-08
# 460    Male         Iraq           Iraq        MiddleSchool         G-08
# 461    Male         Iraq           Iraq        MiddleSchool         G-08
# 462    Male         Iraq           Iraq        MiddleSchool         G-08
# 463    Male         Iraq           Iraq        MiddleSchool         G-08
# 464  Female       Jordan         Jordan        MiddleSchool         G-08
# 465  Female       Jordan         Jordan        MiddleSchool         G-08
# 466  Female       Jordan         Jordan        MiddleSchool         G-08
# 467  Female       Jordan         Jordan        MiddleSchool         G-08
# 470    Male    Palestine         Jordan        MiddleSchool         G-08
# 471    Male    Palestine         Jordan        MiddleSchool         G-08
# 472    Male    Palestine      Palestine        MiddleSchool         G-08
# 473    Male    Palestine      Palestine        MiddleSchool         G-08
#
#     Section ID      Topic Semester Parent responsible for student  \
# 0            A         IT    First                         Father
# 1            A         IT    First                         Father
# 5            A         IT    First                         Father
# 7            A       Math    First                         Father
# 8            A       Math    First                         Father
# 9            B         IT    First                         Father
# 10           A       Math    First                         Father
# 11           B       Math    First                         Father
# 15           A         IT    First                         Father
# 18           A         IT    First                            mom
# 19           B         IT    First                            mom
# 24           B         IT    First                         Father
# 25           A         IT    First                         Father
# 26           B         IT    First                         Father
# 28           A    Science    First                         Father
# 30           A     Arabic    First                         Father
# 31           A         IT    First                         Father
# 32           A         IT    First                         Father
# 36           B    Science    First                            mom
# 37           A         IT    First                         Father
# 39           B    Science    First                         Father
# 42           A         IT    First                         Father
# 43           A         IT    First                         Father
# 47           A    English    First                            mom
# 48           A    English    First                            mom
# 49           A    English    First                         Father
# 53           A    Science    First                            mom
# 55           A       Math    First                         Father
# 56           B       Math    First                         Father
# 57           A       Math    First                         Father
# ..         ...        ...      ...                            ...
# 442          A    History    First                            mom
# 443          A    History   Second                            mom
# 444          A  Chemistry    First                            mom
# 445          A  Chemistry   Second                            mom
# 446          A    Geology    First                            mom
# 447          A    Geology   Second                            mom
# 448          A    History    First                            mom
# 449          A    History   Second                            mom
# 450          A  Chemistry    First                         Father
# 451          A  Chemistry   Second                         Father
# 452          A    Geology    First                         Father
# 453          A    Geology   Second                         Father
# 454          A    History    First                         Father
# 455          A    History   Second                         Father
# 456          A  Chemistry    First                         Father
# 457          A  Chemistry   Second                         Father
# 458          A  Chemistry    First                         Father
# 459          A  Chemistry   Second                         Father
# 460          A    Geology    First                         Father
# 461          A    Geology   Second                         Father
# 462          A    History    First                         Father
# 463          A    History   Second                         Father
# 464          A  Chemistry    First                            mom
# 465          A  Chemistry   Second                            mom
# 466          A    Geology    First                            mom
# 467          A    Geology   Second                            mom
# 470          A    History    First                         Father
# 471          A    History   Second                         Father
# 472          A    Geology    First                         Father
# 473          A    Geology   Second                         Father
#
#      Raised hand  Visited resources  Viewing announcements  Discussion groups  \
# 0             15                 16                      2                 20
# 1             20                 20                      3                 25
# 5             42                 30                     13                 70
# 7             50                 10                     15                 22
# 8             12                 21                     16                 50
# 9             70                 80                     25                 70
# 10            50                 88                     30                 80
# 11            19                  6                     19                 12
# 15            30                 40                     22                 66
# 18            69                 15                     36                 96
# 19            70                 50                     40                 99
# 24             0                  2                      3                 70
# 25             8                  7                     30                 40
# 26            19                 19                     25                 40
# 28            75                 85                     52                 43
# 30            35                 80                     50                 70
# 31             4                  5                     40                 16
# 32             2                 19                     10                 50
# 36             8                  6                      4                 22
# 37            45                 54                     26                 90
# 39            50                 90                     37                 70
# 42            10                 12                      7                 33
# 43            30                 35                     28                 90
# 47            70                  4                     39                 90
# 48            13                 80                     40                 88
# 49            29                 39                     50                 77
# 53            49                 70                     19                 75
# 55            16                 14                      6                 20
# 56            19                  5                      4                  1
# 57             5                  2                      6                  5
# ..           ...                ...                    ...                ...
# 442           69                 77                     76                 75
# 443           70                 76                     65                 70
# 444           75                 72                     64                 39
# 445           72                 76                     66                 40
# 446           77                 82                     74                 79
# 447           71                 84                     67                 80
# 448           87                 92                     74                 89
# 449           81                 84                     77                 85
# 450           15                 97                     22                 10
# 451           19                 98                     20                  2
# 452           25                 82                     52                 20
# 453           29                 78                     40                 12
# 454           45                 87                     57                 80
# 455           39                 88                     43                 72
# 456           85                 90                     52                 30
# 457           79                 91                     49                 22
# 458           90                 91                     80                 81
# 459           80                 90                     80                 83
# 460           80                 83                     82                 71
# 461           71                 81                     83                 72
# 462           72                 87                     72                 89
# 463           69                 77                     83                 92
# 464           85                 99                     42                 90
# 465           89                 96                     45                 92
# 466           80                 82                     64                 58
# 467           87                 93                     63                 60
# 470           81                 86                     86                 41
# 471           78                 82                     78                 53
# 472           80                 87                     74                 68
# 473           85                 88                     79                 70
#
#     Parent Answering Survey ParentschoolSatisfaction StudentAbsenceDays  \
# 0                       Yes                     Good            Under-7
# 1                       Yes                     Good            Under-7
# 5                       Yes                      Bad            Above-7
# 7                       Yes                     Good            Under-7
# 8                       Yes                     Good            Under-7
# 9                       Yes                     Good            Under-7
# 10                      Yes                     Good            Under-7
# 11                      Yes                     Good            Under-7
# 15                      Yes                     Good            Under-7
# 18                      Yes                     Good            Under-7
# 19                      Yes                     Good            Under-7
# 24                      Yes                     Good            Above-7
# 25                      Yes                     Good            Above-7
# 26                      Yes                      Bad            Under-7
# 28                      Yes                     Good            Under-7
# 30                      Yes                     Good            Under-7
# 31                      Yes                     Good            Above-7
# 32                      Yes                     Good            Above-7
# 36                      Yes                     Good            Above-7
# 37                      Yes                     Good            Under-7
# 39                      Yes                     Good            Under-7
# 42                      Yes                     Good            Above-7
# 43                      Yes                     Good            Under-7
# 47                      Yes                     Good            Under-7
# 48                      Yes                     Good            Under-7
# 49                      Yes                     Good            Under-7
# 53                      Yes                     Good            Under-7
# 55                      Yes                     Good            Above-7
# 56                      Yes                     Good            Above-7
# 57                      Yes                     Good            Above-7
# ..                      ...                      ...                ...
# 442                     Yes                     Good            Above-7
# 443                     Yes                     Good            Above-7
# 444                     Yes                     Good            Above-7
# 445                     Yes                     Good            Above-7
# 446                     Yes                     Good            Under-7
# 447                     Yes                     Good            Under-7
# 448                     Yes                     Good            Under-7
# 449                     Yes                     Good            Under-7
# 450                     Yes                     Good            Under-7
# 451                     Yes                     Good            Under-7
# 452                     Yes                     Good            Above-7
# 453                     Yes                     Good            Above-7
# 454                     Yes                     Good            Under-7
# 455                     Yes                     Good            Under-7
# 456                     Yes                     Good            Under-7
# 457                     Yes                     Good            Under-7
# 458                     Yes                     Good            Under-7
# 459                     Yes                     Good            Under-7
# 460                     Yes                     Good            Above-7
# 461                     Yes                     Good            Above-7
# 462                     Yes                     Good            Above-7
# 463                     Yes                     Good            Above-7
# 464                     Yes                     Good            Under-7
# 465                     Yes                     Good            Under-7
# 466                     Yes                     Good            Under-7
# 467                     Yes                     Good            Under-7
# 470                     Yes                     Good            Under-7
# 471                     Yes                     Good            Under-7
# 472                     Yes                     Good            Under-7
# 473                     Yes                     Good            Under-7
#
#             Total
# 0    Middle-Level
# 1    Middle-Level
# 5    Middle-Level
# 7    Middle-Level
# 8    Middle-Level
# 9    Middle-Level
# 10     High-Level
# 11   Middle-Level
# 15   Middle-Level
# 18   Middle-Level
# 19     High-Level
# 24      Low-Level
# 25      Low-Level
# 26   Middle-Level
# 28   Middle-Level
# 30     High-Level
# 31      Low-Level
# 32      Low-Level
# 36      Low-Level
# 37   Middle-Level
# 39   Middle-Level
# 42      Low-Level
# 43   Middle-Level
# 47     High-Level
# 48     High-Level
# 49   Middle-Level
# 53     High-Level
# 55      Low-Level
# 56      Low-Level
# 57      Low-Level
# ..            ...
# 442  Middle-Level
# 443  Middle-Level
# 444     Low-Level
# 445     Low-Level
# 446  Middle-Level
# 447  Middle-Level
# 448    High-Level
# 449    High-Level
# 450    High-Level
# 451    High-Level
# 452  Middle-Level
# 453  Middle-Level
# 454  Middle-Level
# 455  Middle-Level
# 456    High-Level
# 457    High-Level
# 458    High-Level
# 459    High-Level
# 460  Middle-Level
# 461  Middle-Level
# 462  Middle-Level
# 463  Middle-Level
# 464    High-Level
# 465    High-Level
# 466    High-Level
# 467    High-Level
# 470  Middle-Level
# 471  Middle-Level
# 472  Middle-Level
# 473  Middle-Level
#
# [270 rows x 17 columns]

# %%
pss.mean()
# Out:
# Raised hand              54.102740
# Visited resources        64.445205
# Viewing announcements    44.291096
# Discussion groups        44.636986
# dtype: float64

# %%
data.columns
# Out:
# Index(['Gender', 'Nationality', 'Place of birth', 'Educational Stages ',
#        'Grade Levels', 'Section ID', 'Topic', 'Semester',
#        'Parent responsible for student', 'Raised hand', 'Visited resources',
#        'Viewing announcements', 'Discussion groups', 'Parent Answering Survey',
#        'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Total'],
#       dtype='object')

# %%
dt = data.drop(columns =['Gender', 'Nationality', 'Topic', 'Section ID', 'Grade Levels', 'Educational Stages ','Raised hand', 'Visited resources',
       'Viewing announcements', 'Discussion groups', 'StudentAbsenceDays', 'Total', 'Place of birth', 'Semester',
       'Parent responsible for student'])
dt

#column_names={'Gender', 'Nationality', 'Place of birth', 'Educational Stages','Grade Levels', 'Section ID', 'Topic', 'Semester','Parent responsible for student', 'Raised hand', 'Visited resources', 'Viewing announcements', 'Discussion groups', 'StudentAbsenceDays', 'Total'}
#columns_to_drop = [column_names[i] for i in [data]]
# Drop unwanted columns
#data.drop(column_names, inplace=True, axis=1)
# Out:
#     Parent Answering Survey ParentschoolSatisfaction
# 0                       Yes                     Good
# 1                       Yes                     Good
# 2                        No                      Bad
# 3                        No                      Bad
# 4                        No                      Bad
# 5                       Yes                      Bad
# 6                        No                      Bad
# 7                       Yes                     Good
# 8                       Yes                     Good
# 9                       Yes                     Good
# 10                      Yes                     Good
# 11                      Yes                     Good
# 12                       No                      Bad
# 13                       No                      Bad
# 14                       No                      Bad
# 15                      Yes                     Good
# 16                       No                      Bad
# 17                       No                      Bad
# 18                      Yes                     Good
# 19                      Yes                     Good
# 20                       No                      Bad
# 21                       No                      Bad
# 22                       No                      Bad
# 23                       No                      Bad
# 24                      Yes                     Good
# 25                      Yes                     Good
# 26                      Yes                      Bad
# 27                       No                      Bad
# 28                      Yes                     Good
# 29                       No                      Bad
# ..                      ...                      ...
# 450                     Yes                     Good
# 451                     Yes                     Good
# 452                     Yes                     Good
# 453                     Yes                     Good
# 454                     Yes                     Good
# 455                     Yes                     Good
# 456                     Yes                     Good
# 457                     Yes                     Good
# 458                     Yes                     Good
# 459                     Yes                     Good
# 460                     Yes                     Good
# 461                     Yes                     Good
# 462                     Yes                     Good
# 463                     Yes                     Good
# 464                     Yes                     Good
# 465                     Yes                     Good
# 466                     Yes                     Good
# 467                     Yes                     Good
# 468                      No                      Bad
# 469                      No                      Bad
# 470                     Yes                     Good
# 471                     Yes                     Good
# 472                     Yes                     Good
# 473                     Yes                     Good
# 474                      No                      Bad
# 475                      No                      Bad
# 476                      No                      Bad
# 477                      No                      Bad
# 478                      No                      Bad
# 479                      No                      Bad
#
# [480 rows x 2 columns]

# %%
dt['Parent Answering Survey'] == 'Yes'
#The above code will create a bolean answer
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18      True
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29     False
#        ...
# 450     True
# 451     True
# 452     True
# 453     True
# 454     True
# 455     True
# 456     True
# 457     True
# 458     True
# 459     True
# 460     True
# 461     True
# 462     True
# 463     True
# 464     True
# 465     True
# 466     True
# 467     True
# 468    False
# 469    False
# 470     True
# 471     True
# 472     True
# 473     True
# 474    False
# 475    False
# 476    False
# 477    False
# 478    False
# 479    False
# Name: Parent Answering Survey, Length: 480, dtype: bool

# %%
#calling the parents who took a specific action in the dataframe
parentsat = dt.drop(columns = ['Parent Answering Survey'])
parentsat
goodsat=parentsat.loc[parentsat['ParentschoolSatisfaction']=='Good']
goodsat
badsat=parentsat.loc[parentsat['ParentschoolSatisfaction']=='Bad']
badsat
# Out:
#     ParentschoolSatisfaction
# 2                        Bad
# 3                        Bad
# 4                        Bad
# 5                        Bad
# 6                        Bad
# 12                       Bad
# 13                       Bad
# 14                       Bad
# 16                       Bad
# 17                       Bad
# 20                       Bad
# 21                       Bad
# 22                       Bad
# 23                       Bad
# 26                       Bad
# 27                       Bad
# 29                       Bad
# 33                       Bad
# 34                       Bad
# 35                       Bad
# 38                       Bad
# 40                       Bad
# 44                       Bad
# 46                       Bad
# 50                       Bad
# 52                       Bad
# 54                       Bad
# 63                       Bad
# 64                       Bad
# 65                       Bad
# ..                       ...
# 372                      Bad
# 373                      Bad
# 374                      Bad
# 375                      Bad
# 376                      Bad
# 377                      Bad
# 378                      Bad
# 379                      Bad
# 380                      Bad
# 381                      Bad
# 396                      Bad
# 397                      Bad
# 406                      Bad
# 407                      Bad
# 408                      Bad
# 409                      Bad
# 428                      Bad
# 429                      Bad
# 430                      Bad
# 431                      Bad
# 432                      Bad
# 433                      Bad
# 468                      Bad
# 469                      Bad
# 474                      Bad
# 475                      Bad
# 476                      Bad
# 477                      Bad
# 478                      Bad
# 479                      Bad
#
# [188 rows x 1 columns]

# %%
#drop column - parentschool satisfaction

#parentans = dt.drop(columns = ['ParentschoolSatisfaction'])
#parentans
#yans=parentans.loc[parentans['Parent Answering Survey']=='Yes']
#yans
#nans = parentans.loc[parentans['Parent Answering Survey']=='No']
#nans
#nans.describe()

# %%
import seaborn as sns
dt=dt.groupby(['Parent Answering Survey','ParentschoolSatisfaction']).size()
dt=dt.unstack()
dt.plot(kind='bar')

# %%
seta = data.drop(columns =['Gender', 'Nationality', 'Topic', 'Section ID', 'Grade Levels', 'Educational Stages ','Raised hand', 'Visited resources',
       'Viewing announcements', 'Discussion groups', 'StudentAbsenceDays', 'Total', 'Place of birth', 'Semester'])

seta
# Out:
#     Parent responsible for student Parent Answering Survey  \
# 0                           Father                     Yes
# 1                           Father                     Yes
# 2                           Father                      No
# 3                           Father                      No
# 4                           Father                      No
# 5                           Father                     Yes
# 6                           Father                      No
# 7                           Father                     Yes
# 8                           Father                     Yes
# 9                           Father                     Yes
# 10                          Father                     Yes
# 11                          Father                     Yes
# 12                          Father                      No
# 13                          Father                      No
# 14                             mom                      No
# 15                          Father                     Yes
# 16                          Father                      No
# 17                          Father                      No
# 18                             mom                     Yes
# 19                             mom                     Yes
# 20                          Father                      No
# 21                          Father                      No
# 22                          Father                      No
# 23                          Father                      No
# 24                          Father                     Yes
# 25                          Father                     Yes
# 26                          Father                     Yes
# 27                          Father                      No
# 28                          Father                     Yes
# 29                          Father                      No
# ..                             ...                     ...
# 450                         Father                     Yes
# 451                         Father                     Yes
# 452                         Father                     Yes
# 453                         Father                     Yes
# 454                         Father                     Yes
# 455                         Father                     Yes
# 456                         Father                     Yes
# 457                         Father                     Yes
# 458                         Father                     Yes
# 459                         Father                     Yes
# 460                         Father                     Yes
# 461                         Father                     Yes
# 462                         Father                     Yes
# 463                         Father                     Yes
# 464                            mom                     Yes
# 465                            mom                     Yes
# 466                            mom                     Yes
# 467                            mom                     Yes
# 468                         Father                      No
# 469                         Father                      No
# 470                         Father                     Yes
# 471                         Father                     Yes
# 472                         Father                     Yes
# 473                         Father                     Yes
# 474                         Father                      No
# 475                         Father                      No
# 476                         Father                      No
# 477                         Father                      No
# 478                         Father                      No
# 479                         Father                      No
#
#     ParentschoolSatisfaction
# 0                       Good
# 1                       Good
# 2                        Bad
# 3                        Bad
# 4                        Bad
# 5                        Bad
# 6                        Bad
# 7                       Good
# 8                       Good
# 9                       Good
# 10                      Good
# 11                      Good
# 12                       Bad
# 13                       Bad
# 14                       Bad
# 15                      Good
# 16                       Bad
# 17                       Bad
# 18                      Good
# 19                      Good
# 20                       Bad
# 21                       Bad
# 22                       Bad
# 23                       Bad
# 24                      Good
# 25                      Good
# 26                       Bad
# 27                       Bad
# 28                      Good
# 29                       Bad
# ..                       ...
# 450                     Good
# 451                     Good
# 452                     Good
# 453                     Good
# 454                     Good
# 455                     Good
# 456                     Good
# 457                     Good
# 458                     Good
# 459                     Good
# 460                     Good
# 461                     Good
# 462                     Good
# 463                     Good
# 464                     Good
# 465                     Good
# 466                     Good
# 467                     Good
# 468                      Bad
# 469                      Bad
# 470                     Good
# 471                     Good
# 472                     Good
# 473                     Good
# 474                      Bad
# 475                      Bad
# 476                      Bad
# 477                      Bad
# 478                      Bad
# 479                      Bad
#
# [480 rows x 3 columns]

# %%
#representing the relationship between the parent answering survey, school satisfaction and the parent responsible for the student
seta=seta.groupby(['Parent Answering Survey','ParentschoolSatisfaction','Parent responsible for student' ]).size()
seta=seta.unstack()
seta.plot(kind='bar')
